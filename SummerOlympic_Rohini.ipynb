# %%
Project Name : Summer Olympic.csv

# %%
import numpy as np
import pandas as pd                  #import libraries of numpy and pandas to use its features in data visualizationolympic = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/summer%20olympics.csv")
olympic

# View dataset to start data visualization
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %%
olympic.shape
#How many rows and columns in the dataset#
# Out:
# (31165, 9)

# %%
olympic.dtypes
#What are the datatypes of each column#
# Out:
# Year           int64
# City          object
# Sport         object
# Discipline    object
# Athlete       object
# Country       object
# Gender        object
# Event         object
# Medal         object
# dtype: object

# %%
import pandas_profiling                                                      # Get a quick overview for all the variables using pandas_profiling                                         
profile = pandas_profiling.ProfileReport(olympic)
profile.to_file(outputfile="olympic.html")                              # HTML file will be downloaded to your workspace

# %%
olympic.info()                                            #to check missing infor from dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31165 non-null int64
# City          31165 non-null object
# Sport         31165 non-null object
# Discipline    31165 non-null object
# Athlete       31165 non-null object
# Country       31161 non-null object
# Gender        31165 non-null object
# Event         31165 non-null object
# Medal         31165 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
olympic["Country"].isnull().values.any().sum()                         #to check if there is any Nan value present in Country col
# Out:
# 1

# %%
olympic.describe(include = 'all                                #to study high level info on each col
# Out:
#                 Year    City     Sport Discipline          Athlete Country  \
# count   31165.000000   31165     31165      31165            31165   31161
# unique           NaN      22        43         67            22762     147
# top              NaN  London  Aquatics  Athletics  PHELPS, Michael     USA
# freq             NaN    3567      4170       3638               22    4585
# mean     1970.482785     NaN       NaN        NaN              NaN     NaN
# std        33.158416     NaN       NaN        NaN              NaN     NaN
# min      1896.000000     NaN       NaN        NaN              NaN     NaN
# 25%      1948.000000     NaN       NaN        NaN              NaN     NaN
# 50%      1980.000000     NaN       NaN        NaN              NaN     NaN
# 75%      2000.000000     NaN       NaN        NaN              NaN     NaN
# max      2012.000000     NaN       NaN        NaN              NaN     NaN
#
#        Gender     Event  Medal
# count   31165     31165  31165
# ...

# %%
olympic.head(10)
# Out:
#    Year    City     Sport Discipline                Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming       HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 6  1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 7  1896  Athens  Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
# 8  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 9  1896  Athens  Aquatics   Swimming          NEUMANN, Paul     AUT    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# ...

# %%
olympic.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
# Out:
#        Year                   City              Sport       Discipline  \
# 500    1900                  Paris             Rowing           Rowing
# 25061  2000                 Sydney         Volleyball       Volleyball
# 22346  1996                Atlanta         Gymnastics      Artistic G.
# 19522  1988                  Seoul      Weightlifting    Weightlifting
# 6146   1932            Los Angeles  Modern Pentathlon  Modern Pentath.
# 1872   1908                 London             Tennis           Tennis
# 11610  1964                  Tokyo         Volleyball       Volleyball
# 10842  1964                  Tokyo          Athletics        Athletics
# 9334   1956  Melbourne / Stockholm            Fencing          Fencing
# 5260   1928              Amsterdam            Cycling    Cycling Track
# 11258  1964                  Tokyo           Football         Football
# 3144   1920                Antwerp            Cycling     Cycling Road
# ...

# %%
olympic.drop_duplicates()                                   
                                                # Ensures there is no duplicate rows in the dataset
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %%
olympic.Discipline.unique()           
                                                #To check how many types of sports are there in dataset
# Out:
# array(['Swimming', 'Athletics', 'Cycling Road', 'Cycling Track',
#        'Fencing', 'Artistic G.', 'Shooting', 'Tennis', 'Weightlifting',
#        'Wrestling Gre-R', 'Water polo', 'Archery', 'Basque Pelota',
#        'Cricket', 'Croquet', 'Jumping', 'Football', 'Golf', 'Polo',
#        'Rowing', 'Rugby', 'Sailing', 'Tug of War', 'Diving', 'Boxing',
#        'Lacrosse', 'Roque', 'Wrestling Free.', 'Hockey', 'Jeu de Paume',
#        'Rackets', 'Figure skating', 'Water Motorspor', 'Dressage',
#        'Eventing', 'Modern Pentath.', 'Vaulting', 'Ice Hockey',
#        'Basketball', 'Canoe / Kayak F', 'Handball', 'Judo', 'Volleyball',
#        'Canoe / Kayak S', 'Synchronized S.', 'Rhythmic G.',
#        'Table Tennis', 'Badminton', 'Baseball', 'Mountain Bike',
#        'Softball', 'Beach volley.', 'Trampoline', 'Taekwondo',
#        'Triathlon', 'BMX', 'Marathon swimming', 'Synchronized Swimming',
#        'Water Polo', 'Canoe Slalom', 'Canoe Sprint', 'Cycling BMX',
# ...

# %%
print(olympic[(olympic["Sport"]=='Aquatics') & (olympic["Discipline"]=='Swimming') & 
(olympic["Medal"] == 'Gold') & (olympic["Year"]==1896)])
                                            #Looking at one Year data
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 6  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 9  1896  Athens  Aquatics   Swimming       NEUMANN, Paul     AUT    Men
#
#                         Event Medal
# 0              100M Freestyle  Gold
# 3  100M Freestyle For Sailors  Gold
# 6             1200M Freestyle  Gold
# 9              400M Freestyle  Gold

# %%
print(olympic[(olympic["Gender"]=='Women') & (olympic["Medal"] == 'Gold')]).count()

        #there are 2788 total gold medals won by Women out of 10486 total Gold Medals
# Out:
#        Year       City          Sport           Discipline  \
# 417    1900      Paris           Golf                 Golf
# 641    1900      Paris         Tennis               Tennis
# 649    1900      Paris         Tennis               Tennis
# 710    1904   St Louis        Archery              Archery
# 713    1904   St Louis        Archery              Archery
# 730    1904   St Louis        Archery              Archery
# 731    1904   St Louis        Archery              Archery
# 732    1904   St Louis        Archery              Archery
# 733    1904   St Louis        Archery              Archery
# 1185   1908     London        Archery              Archery
# 1843   1908     London        Skating       Figure skating
# 1849   1908     London        Skating       Figure skating
# 1870   1908     London         Tennis               Tennis
# 1876   1908     London         Tennis               Tennis
# 1941   1912  Stockholm       Aquatics               Diving
# ...

# %%
print(olympic[(olympic["Gender"]=='Men') & (olympic["Medal"] == 'Gold')]).count()

#Men's won 7698 Gold Medals Vs 2788 by Women of Total 10486 Gold Medals
# Out:
#        Year    City          Sport           Discipline  \
# 0      1896  Athens       Aquatics             Swimming
# 3      1896  Athens       Aquatics             Swimming
# 6      1896  Athens       Aquatics             Swimming
# 9      1896  Athens       Aquatics             Swimming
# 13     1896  Athens      Athletics            Athletics
# 15     1896  Athens      Athletics            Athletics
# 18     1896  Athens      Athletics            Athletics
# 21     1896  Athens      Athletics            Athletics
# 24     1896  Athens      Athletics            Athletics
# 27     1896  Athens      Athletics            Athletics
# 29     1896  Athens      Athletics            Athletics
# 33     1896  Athens      Athletics            Athletics
# 36     1896  Athens      Athletics            Athletics
# 40     1896  Athens      Athletics            Athletics
# 43     1896  Athens      Athletics            Athletics
# 46     1896  Athens      Athletics            Athletics
# ...

# %%
olympic["Medal"] = olympic["Medal"].replace("Gold", 1)

# Tried replacing Gold. Silver and Bronze by 1,2,3 to graph more clear but drop the idea

# %%
olympic.Sport.unique()
                #To check what differen sports categories are in Summer athletics
# Out:
# array(['Aquatics', 'Athletics', 'Cycling', 'Fencing', 'Gymnastics',
#        'Shooting', 'Tennis', 'Weightlifting', 'Wrestling', 'Archery',
#        'Basque Pelota', 'Cricket', 'Croquet', 'Equestrian', 'Football',
#        'Golf', 'Polo', 'Rowing', 'Rugby', 'Sailing', 'Tug of War',
#        'Boxing', 'Lacrosse', 'Roque', 'Hockey', 'Jeu de paume', 'Rackets',
#        'Skating', 'Water Motorsports', 'Modern Pentathlon', 'Ice Hockey',
#        'Basketball', 'Canoe / Kayak', 'Handball', 'Judo', 'Volleyball',
#        'Table Tennis', 'Badminton', 'Baseball', 'Softball', 'Taekwondo',
#        'Triathlon', 'Canoe'], dtype=object)

# %%
olympic.Gender.unique()
                                                To confirm there are only 2 unique values in Gender
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
she = pd.DataFrame(olympic, columns=['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender', 'Event', 'Medal'])
she
                    #Created a duplicate dataset to study the Women's progression in Summer Olympic
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %%
she = she[(she['Gender']=='Women')]
she
                        #Filter Duplicate dataset to extract rows related to Women
# Out:
#        Year      City          Sport           Discipline  \
# 416    1900     Paris           Golf                 Golf
# 417    1900     Paris           Golf                 Golf
# 418    1900     Paris           Golf                 Golf
# 639    1900     Paris         Tennis               Tennis
# 640    1900     Paris         Tennis               Tennis
# 641    1900     Paris         Tennis               Tennis
# 642    1900     Paris         Tennis               Tennis
# 647    1900     Paris         Tennis               Tennis
# 648    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 650    1900     Paris         Tennis               Tennis
# 709    1904  St Louis        Archery              Archery
# 710    1904  St Louis        Archery              Archery
# 711    1904  St Louis        Archery              Archery
# 712    1904  St Louis        Archery              Archery
# ...

# %%
she.shape
                        # No of Rows & Columns of Women's Dataset
# Out:
# (8419, 9)

# %%
she.set_index(['Year', 'Sport','City']).sum(level=[0, 1]).applymap(' '.join).reset_index()
                                            #Learning Index
# Out:
#      Year              Sport  \
# 0    1900               Golf
# 1    1900             Tennis
# 2    1904            Archery
# 3    1908            Archery
# 4    1908            Skating
# 5    1908             Tennis
# 6    1912           Aquatics
# 7    1912             Tennis
# 8    1920           Aquatics
# 9    1920            Sailing
# 10   1920            Skating
# 11   1920             Tennis
# 12   1924           Aquatics
# 13   1924         Equestrian
# 14   1924            Fencing
# 15   1924             Tennis
# 16   1928           Aquatics
# 17   1928          Athletics
# 18   1928         Equestrian
# 19   1928            Fencing
# 20   1928         Gymnastics
# 21   1928            Sailing
# 22   1932           Aquatics
# 23   1932          Athletics
# 24   1932            Fencing
# 25   1936           Aquatics
# 26   1936          Athletics
# 27   1936            Fencing
# 28   1936         Gymnastics
# 29   1948           Aquatics
# ..    ...                ...
# ...

# %%
olympic.groupby('Year')['Gender'].count()     #to get a count of female particiation in various sports
# Out:
# Year
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# 2012    1949
# Name: Gender, dtype: int64

# %%
import matplotlib as mat
(olympic.groupby('Year')['Gender'].count()).plot.line()        #to view on graph get a count of particiation in various sports

# %%
import matplotlib as mat
(she.groupby('Year')['Gender'].count()).plot.line()        #to view on graph get a count of particiation in various sports

# %%
import matplotlib as mat
(she.groupby('Year')['Country'].count()).plot.line()        #to view on graph get a count of  particiation of various countries

# %%
she.groupby('Sport')['Gender'].count()
# Out:
# Sport
# Aquatics             1726
# Archery               111
# Athletics            1163
# Badminton              72
# Basketball            359
# Boxing                 12
# Canoe                  27
# Canoe / Kayak         228
# Cycling               136
# Equestrian            198
# Fencing               316
# Football              264
# Golf                    3
# Gymnastics            799
# Handball              429
# Hockey                431
# Judo                  168
# Modern Pentathlon      12
# Rowing                651
# Sailing               109
# Shooting              128
# Skating                12
# Softball              180
# Table Tennis           72
# Taekwondo              56
# Tennis                120
# Triathlon              12
# Volleyball            497
# Weightlifting          84
# Wrestling              44
# Name: Gender, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,7))
she.groupby('Sport')['Gender'].count().plot(ax=ax)

# %%
she.set_index(['Year', 'Sport','City','Discipline','Event', 'Country'])
# Out:
#                                                                                                                              Athlete  \
# Year Sport         City     Discipline          Event                                   Country
# 1900 Golf          Paris    Golf                Individual                              USA                             PRATT, Daria
#                                                                                         USA                    ABBOTT, Margaret Ives
#                                                                                         USA                        WHITTIER, Pauline
#      Tennis        Paris    Tennis              Mixed Doubles                           ZZX                            JONES, Marion
#                                                                                         ZZX                        ROSENBAUM, Hedwig
# ...

# %%
(she.groupby(['Year','Country' ,'Medal','Athlete'])['Medal'].count())
# Out:
# Year  Country  Medal   Athlete
# 1900  BOH      Bronze  ROSENBAUM, Hedwig                1
#       FRA      Silver  PREVOST, Hélène                  1
#       GBR      Gold    COOPER, Charlotte                2
#       USA      Bronze  JONES, Marion                    1
#                        PRATT, Daria                     1
#                Gold    ABBOTT, Margaret Ives            1
#                Silver  WHITTIER, Pauline                1
#       ZZX      Bronze  JONES, Marion                    1
#                        ROSENBAUM, Hedwig                1
#                Silver  PREVOST, Hélène                  1
# 1904  USA      Bronze  POLLOCK, Jessie                  2
#                Gold    HOWELL, Matilda Scott            3
#                        POLLOCK, Jessie                  1
#                        TAYLOR, Louise                   1
#                        WOODRUFF, Laura                  1
#                Silver  COOKE, Emma C.                   3
# ...

# %%
(olympic.groupby(['Country', 'Medal'])['Medal'].count())
# Out:
# Country  Medal
# AFG      Bronze       2
# AHO      Silver       1
# ALG      Bronze       8
#          Gold         5
#          Silver       2
# ANZ      Bronze       5
#          Gold        20
#          Silver       4
# ARG      Bronze      91
#          Gold        69
#          Silver      99
# ARM      Bronze       8
#          Gold         1
#          Silver       2
# AUS      Bronze     472
#          Gold       312
#          Silver     405
# AUT      Bronze      44
#          Gold        21
#          Silver      81
# AZE      Bronze      15
#          Gold         6
#          Silver       5
# BAH      Bronze       5
#          Gold        13
#          Silver       9
# BAR      Bronze       1
# BDI      Gold         1
# BEL      Bronze     152
#          Gold        91
#                    ...
# UKR      Bronze      90
#          Gold        41
#          Silver      42
# URS      Bronze     584
#          Gold       838
#          Silver     627
# ...

# %%
(she.groupby(['Country', 'Medal'])['Medal'].count()).plot.line()  # Maximum no of Gold Medal won by Country

# %%
print("% of women Gold: " , she[she.Medal == 'Gold']['Medal'].count() / olympic[olympic.Medal == 'Gold']['Medal'].count() * 100)
print("% of Men Gold", (olympic[olympic.Medal == 'Gold']['Medal'].count() - she[she.Medal == 'Gold']['Medal'].count() )/olympic[olympic.Medal == 'Gold']['Medal'].count()*100)
# Out:
# % of women Gold:  26.58783139423994
# % of Men Gold 73.41216860576006

# %%
import pandas as pd
from collections import Counter
count  = pd.Series(she['Medal'].str.replace('[\[\]\']','').str.split(',').map(Counter).sum())
count
# Out:
# Bronze    2830
# Gold      2788
# Silver    2801
# dtype: int64

# %%
she[she.Medal == 'Gold']['Medal'].count()
# Out:
# 2788

# %%
import matplotlib.pyplot as plt
fig,ax =plt.subplots(figsize=(8,8))
sns.countplot(data = olympic,x = 'Year', hue='Medal')
plt.title('Year vs Medal')
# Out:
# Text(0.5, 1.0, 'Year vs Medal')

# %%
sns.countplot(x='Gender', data=olympic).set_title('Count plot for Gender.')
# Out:
# Text(0.5, 1.0, 'Count plot for Gender.')

# %%
(olympic[(olympic["Sport"]=='Aquatics') & (olympic["Discipline"]=='Swimming') & (olympic["Gender"]== 'Men')]).plot.line()

# %%
import matplotlib.pyplot as plt
plt.scatter(x=olympic['Year'], y=olympic['Gender'])
plt.show()
# Out:
# C:\Users\Kishor\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
